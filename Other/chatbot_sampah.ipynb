# %%
# !gdown 1MmJtib8_P0i5kMrIyEfdgDH_Okwlr8aY #download dataset

# %%
# Import Library
import json
import numpy as np
import pandas as pd
import tensorflow as tf
import nltk
import random
import string
import matplotlib.pyplot as plt
from nltk.stem import WordNetLemmatizer
from tensorflow.keras.models import Model
from keras.utils.vis_utils import plot_model
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.layers import Input, Embedding, LSTM, Dropout, GlobalMaxPool1D, Bidirectional, Conv1D, MaxPooling1D, Bidirectional, GRU
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import regularizers
from sklearn.model_selection import train_test_split
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.layers import Flatten, Dense, GlobalMaxPool1D

# %%
with open('waste_management3.json', encoding='utf-8') as content:
  data = json.load(content)

# %%
# Package sentence tokenizer
nltk.download('punkt')
# Package lemmatization
nltk.download('wordnet')
# Package multilingual wordnet data
nltk.download('omw-1.4')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\biman\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\biman\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\biman\AppData\Roaming\nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# True

# %%
# Mendapatkan semua data ke dalam list
tags = [] # data tag
inputs = [] # data input atau pattern
responses = {} # data respon
words = [] # Data kata
classes = [] # Data Kelas atau Tag
documents = [] # Data Kalimat Dokumen
ignore_words = ['?', '!'] # Mengabaikan tanda spesial karakter

for intent in data['intents']:
  responses[intent['tag']]=intent['responses']
  for lines in intent['patterns']:
    inputs.append(lines)
    tags.append(intent['tag'])
    for pattern in intent['patterns']:
      w = nltk.word_tokenize(pattern)
      words.extend(w)
      documents.append((w, intent['tag']))
      # add to our classes list
      if intent['tag'] not in classes:
        classes.append(intent['tag'])

# Konversi data json ke dalam dataframe
# data = pd.DataFrame({"patterns":inputs, "tags":tags})

# %%
# Split dataset into training set and test set
X_train, X_test, y_train, y_test = train_test_split(inputs, tags,test_size=0.2, random_state=42)

# Konversi data ke dalam dataframe
train_data = pd.DataFrame({"patterns": X_train, "tags": y_train})
test_data = pd.DataFrame({"patterns": X_test, "tags": y_test})

# %%
train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 189 entries, 0 to 188
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   patterns  189 non-null    object
#  1   tags      189 non-null    object
# dtypes: object(2)
# memory usage: 3.1+ KB

# %%
test_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48 entries, 0 to 47
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   patterns  48 non-null     object
#  1   tags      48 non-null     object
# dtypes: object(2)
# memory usage: 896.0+ bytes

# %%
train_data.head()
# Out:
#                                             patterns  \
# 0         Apa manfaat dari pengolahan limbah sampah?
# 1                    Apa itu pengolahan limbah kaca?
# 2  Berikan penjelasan nilai yang dihasilkan dari ...
# 3          jelaskan langkah dalam pengolahan limbah?
# 4    Bagaimana cara menghasilkan biogas dari limbah?
#
#                                tags
# 0  manfaat_pengolahan_limbah_sampah
# 1            pengolahan_limbah_kaca
# 2             nilai_pengolahan_kaca
# 3         langkah_pengolahan_limbah
# 4                 pengolahan_biogas

# %%
test_data.head()
# Out:
#                                             patterns                     tags
# 0  apa daur ulang limbah sampah itu penting? kena...    pentingnya_daur_ulang
# 1                                           chatbotx                 greeting
# 2      Manfaat dari pengolahan limbah kaca apa saja?  manfaat_pengolahan_kaca
# 3  berikan jenis atau contoh limbah sampah yang b...  jenis_sampah_daur_ulang
# 4                                               pagi                 greeting

# %%
train_data['patterns'] = train_data['patterns'].apply(lambda wrd: [ltrs.lower() for ltrs in wrd if ltrs not in string.punctuation])
train_data['patterns'] = train_data['patterns'].apply(lambda wrd: ''.join(wrd))
test_data['patterns'] = test_data['patterns'].apply(lambda wrd: [ltrs.lower() for ltrs in wrd if ltrs not in string.punctuation])
test_data['patterns'] = test_data['patterns'].apply(lambda wrd: ''.join(wrd))

# %%
# Inisialisasi Lemmatizer
lemmatizer = WordNetLemmatizer()

# Fungsi untuk melakukan lemmatization pada kata-kata dalam kalimat
def lemmatize_text(text):
    tokens = nltk.word_tokenize(text)  # Tokenisasi kata-kata dalam kalimat
    lemmatized_tokens = [lemmatizer.lemmatize(token) for token in tokens]  # Lemmatization
    lemmatized_text = ' '.join(lemmatized_tokens)  # Menggabungkan kembali kata-kata menjadi kalimat
    return lemmatized_text

# Contoh penggunaan fungsi lemmatize_text pada dataset
train_data['patterns'] = train_data['patterns'].apply(lemmatize_text)
test_data['patterns'] = test_data['patterns'].apply(lemmatize_text)

# %%
# Tokenize the data (Tokenisasi Data)
tokenizer = Tokenizer(num_words=2000)
tokenizer.fit_on_texts(train_data['patterns'])

x_train = tokenizer.texts_to_sequences(train_data['patterns'])
x_test = tokenizer.texts_to_sequences(test_data['patterns'])

# %%
# Apply padding
max_sequence_length = max(len(seq) for seq in x_train + x_test)
x_train = pad_sequences(x_train, maxlen=max_sequence_length)
x_test = pad_sequences(x_test, maxlen=max_sequence_length)

# %%
# Combine tags from train_data and test_data
all_tags = list(set(train_data['tags']) | set(test_data['tags']))

# Encoding the outputs
le = LabelEncoder()
le.fit(all_tags)

y_train = le.transform(train_data['tags'])
y_test = le.transform(test_data['tags'])

# %%
# Splitting the dataset
train_dataset = (x_train, y_train)
test_dataset = (x_test, y_test)

# %%
# Creating the model
# Menambahkan regularisasi L2
regularization = regularizers.l2(0.01)

# Mengubah tingkat dropout menjadi 0.5
dropout_rate = 0.5

# Mendefinisikan input layer
i = Input(shape=(max_sequence_length,))

# Embedding layer
embedding_size = 100
x = Embedding(len(tokenizer.word_index) + 1, embedding_size)(i)

# Bidirectional LSTM layer
lstm_units = 32
x = Bidirectional(LSTM(lstm_units, return_sequences=True))(x)

# Bidirectional GRU layer
gru_units = 64
x = Bidirectional(GRU(gru_units, return_sequences=True))(x)

# Flatten layer
x = Flatten()(x)

# Dense layer with L2 regularization
dense_units = 50
x = Dense(dense_units, activation='relu', kernel_regularizer=regularization)(x)
x = Dropout(dropout_rate)(x)

# Output layer
num_classes = len(classes)
x = Dense(num_classes, activation="softmax")(x)
model = Model(i, x)

model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 16)]              0
#
#  embedding (Embedding)       (None, 16, 100)           16600
#
#  bidirectional (Bidirectiona  (None, 16, 64)           34048
#  l)
#
#  bidirectional_1 (Bidirectio  (None, 16, 128)          49920
#  nal)
#
#  flatten (Flatten)           (None, 2048)              0
#
#  dense (Dense)               (None, 50)                102450
#
#  dropout (Dropout)           (None, 50)                0
#
#  dense_1 (Dense)             (None, 37)                1887
#
# =================================================================
# Total params: 204,905
# Trainable params: 204,905
# Non-trainable params: 0
# _________________________________________________________________

# %%
class myCallback(tf.keras.callbacks.Callback):
    # Define the method that checks the accuracy at the end of each epoch
    def on_epoch_end(self, epoch, logs={}):
        if logs.get('val_accuracy') > 0.8:
            print("\nReached 0.7 val acc so cancelling training!")

            # Stop training once the above condition is met
            self.model.stop_training = True

# %%
learning_rate = 0.001
optimizer = Adam(learning_rate=learning_rate)
# Instantiate the callback class
cb = myCallback()

# %%
# Compiling the model
model.compile(loss="sparse_categorical_crossentropy", optimizer=optimizer, metrics=['accuracy'])

# %%
# Training the model
batch_size=32
history = model.fit(train_dataset[0], train_dataset[1], epochs=500, callbacks = [cb], validation_data=test_dataset)
# Out:
# Epoch 1/500
# 6/6 [==============================] - 9s 310ms/step - loss: 4.4740 - accuracy: 0.0265 - val_loss: 4.3144 - val_accuracy: 0.0625
# Epoch 2/500
# 6/6 [==============================] - 0s 28ms/step - loss: 4.2185 - accuracy: 0.0212 - val_loss: 4.1071 - val_accuracy: 0.0417
# Epoch 3/500
# 6/6 [==============================] - 0s 24ms/step - loss: 4.0135 - accuracy: 0.0476 - val_loss: 3.9569 - val_accuracy: 0.0417
# Epoch 4/500
# 6/6 [==============================] - 0s 23ms/step - loss: 3.8619 - accuracy: 0.0529 - val_loss: 3.8405 - val_accuracy: 0.0417
# Epoch 5/500
# 6/6 [==============================] - 0s 23ms/step - loss: 3.7378 - accuracy: 0.0370 - val_loss: 3.7256 - val_accuracy: 0.0625
# Epoch 6/500
# 6/6 [==============================] - 0s 23ms/step - loss: 3.6161 - accuracy: 0.0635 - val_loss: 3.5881 - val_accuracy: 0.0417
# Epoch 7/500
# 6/6 [==============================] - 0s 23ms/step - loss: 3.4595 - accuracy: 0.0952 - val_loss: 3.4566 - val_accuracy: 0.0417
# Epoch 8/500
# 6/6 [==============================] - 0s 25ms/step - loss: 3.4292 - accuracy: 0.0476 - val_loss: 3.3738 - val_accuracy: 0.0625
# Epoch 9/500
# 6/6 [==============================] - 0s 23ms/step - loss: 3.3456 - accuracy: 0.0635 - val_loss: 3.3611 - val_accuracy: 0.0625
# Epoch 10/500
# 6/6 [==============================] - 0s 22ms/step - loss: 3.2540 - accuracy: 0.0741 - val_loss: 3.3265 - val_accuracy: 0.0625
# Epoch 11/500
# 6/6 [==============================] - 0s 22ms/step - loss: 3.1916 - accuracy: 0.0794 - val_loss: 3.3062 - val_accuracy: 0.0833
# Epoch 12/500
# 6/6 [==============================] - 0s 28ms/step - loss: 3.1872 - accuracy: 0.0899 - val_loss: 3.3191 - val_accuracy: 0.0833
# Epoch 13/500
# 6/6 [==============================] - 0s 26ms/step - loss: 3.1390 - accuracy: 0.1217 - val_loss: 3.2818 - val_accuracy: 0.0833
# Epoch 14/500
# 6/6 [==============================] - 0s 25ms/step - loss: 3.0490 - accuracy: 0.1323 - val_loss: 3.2710 - val_accuracy: 0.0625
# Epoch 15/500
# 6/6 [==============================] - 0s 25ms/step - loss: 2.9444 - accuracy: 0.1958 - val_loss: 3.2081 - val_accuracy: 0.1458
# Epoch 16/500
# 6/6 [==============================] - 0s 23ms/step - loss: 2.9294 - accuracy: 0.1640 - val_loss: 3.2432 - val_accuracy: 0.1042
# Epoch 17/500
# 6/6 [==============================] - 0s 22ms/step - loss: 2.8588 - accuracy: 0.1217 - val_loss: 3.1604 - val_accuracy: 0.1458
# Epoch 18/500
# 6/6 [==============================] - 0s 23ms/step - loss: 2.8450 - accuracy: 0.1799 - val_loss: 3.1554 - val_accuracy: 0.1250
# Epoch 19/500
# 6/6 [==============================] - 0s 31ms/step - loss: 2.6256 - accuracy: 0.2698 - val_loss: 3.0827 - val_accuracy: 0.2083
# Epoch 20/500
# 6/6 [==============================] - 0s 26ms/step - loss: 2.5844 - accuracy: 0.2275 - val_loss: 3.1543 - val_accuracy: 0.1458
# Epoch 21/500
# 6/6 [==============================] - 0s 23ms/step - loss: 2.4020 - accuracy: 0.3122 - val_loss: 3.2300 - val_accuracy: 0.0625
# Epoch 22/500
# 6/6 [==============================] - 0s 23ms/step - loss: 2.4248 - accuracy: 0.2857 - val_loss: 3.0465 - val_accuracy: 0.1667
# Epoch 23/500
# 6/6 [==============================] - 0s 24ms/step - loss: 2.4338 - accuracy: 0.2910 - val_loss: 2.9018 - val_accuracy: 0.1667
# Epoch 24/500
# 6/6 [==============================] - 0s 33ms/step - loss: 2.3096 - accuracy: 0.2857 - val_loss: 2.8440 - val_accuracy: 0.2708
# Epoch 25/500
# 6/6 [==============================] - 0s 23ms/step - loss: 2.3237 - accuracy: 0.3122 - val_loss: 2.8254 - val_accuracy: 0.2500
# Epoch 26/500
# 6/6 [==============================] - 0s 23ms/step - loss: 2.2207 - accuracy: 0.2910 - val_loss: 2.8664 - val_accuracy: 0.1667
# Epoch 27/500
# 6/6 [==============================] - 0s 23ms/step - loss: 2.1513 - accuracy: 0.3333 - val_loss: 2.8099 - val_accuracy: 0.2500
# Epoch 28/500
# 6/6 [==============================] - 0s 23ms/step - loss: 2.0610 - accuracy: 0.4021 - val_loss: 2.9267 - val_accuracy: 0.3125
# Epoch 29/500
# 6/6 [==============================] - 0s 23ms/step - loss: 1.8425 - accuracy: 0.4339 - val_loss: 2.8598 - val_accuracy: 0.3333
# Epoch 30/500
# 6/6 [==============================] - 0s 22ms/step - loss: 1.7888 - accuracy: 0.4656 - val_loss: 2.8485 - val_accuracy: 0.2917
# Epoch 31/500
# 6/6 [==============================] - 0s 22ms/step - loss: 1.6507 - accuracy: 0.4921 - val_loss: 2.9720 - val_accuracy: 0.3333
# Epoch 32/500
# 6/6 [==============================] - 0s 22ms/step - loss: 1.6710 - accuracy: 0.4339 - val_loss: 2.7384 - val_accuracy: 0.2917
# Epoch 33/500
# 6/6 [==============================] - 0s 22ms/step - loss: 1.6815 - accuracy: 0.4550 - val_loss: 2.8348 - val_accuracy: 0.3542
# Epoch 34/500
# 6/6 [==============================] - 0s 23ms/step - loss: 1.5656 - accuracy: 0.5238 - val_loss: 2.7486 - val_accuracy: 0.3333
# Epoch 35/500
# 6/6 [==============================] - 0s 22ms/step - loss: 1.5706 - accuracy: 0.4815 - val_loss: 2.9645 - val_accuracy: 0.3542
# Epoch 36/500
# 6/6 [==============================] - 0s 24ms/step - loss: 1.4219 - accuracy: 0.5767 - val_loss: 2.8311 - val_accuracy: 0.3542
# Epoch 37/500
# 6/6 [==============================] - 0s 27ms/step - loss: 1.4915 - accuracy: 0.5661 - val_loss: 2.7830 - val_accuracy: 0.3125
# Epoch 38/500
# 6/6 [==============================] - 0s 26ms/step - loss: 1.4920 - accuracy: 0.5608 - val_loss: 2.8232 - val_accuracy: 0.3958
# Epoch 39/500
# 6/6 [==============================] - 0s 23ms/step - loss: 1.3088 - accuracy: 0.6085 - val_loss: 2.7734 - val_accuracy: 0.4583
# Epoch 40/500
# 6/6 [==============================] - 0s 22ms/step - loss: 1.4295 - accuracy: 0.5661 - val_loss: 2.7501 - val_accuracy: 0.4375
# Epoch 41/500
# 6/6 [==============================] - 0s 27ms/step - loss: 1.2609 - accuracy: 0.5926 - val_loss: 2.6706 - val_accuracy: 0.3958
# Epoch 42/500
# 6/6 [==============================] - 0s 24ms/step - loss: 1.1803 - accuracy: 0.6825 - val_loss: 2.7131 - val_accuracy: 0.3125
# Epoch 43/500
# 6/6 [==============================] - 0s 23ms/step - loss: 1.1610 - accuracy: 0.6508 - val_loss: 2.7168 - val_accuracy: 0.5000
# Epoch 44/500
# 6/6 [==============================] - 0s 23ms/step - loss: 1.1268 - accuracy: 0.6825 - val_loss: 2.9203 - val_accuracy: 0.3958
# Epoch 45/500
# 6/6 [==============================] - 0s 23ms/step - loss: 1.0058 - accuracy: 0.7196 - val_loss: 2.7272 - val_accuracy: 0.3750
# Epoch 46/500
# 6/6 [==============================] - 0s 30ms/step - loss: 0.9868 - accuracy: 0.7302 - val_loss: 2.7443 - val_accuracy: 0.5625
# Epoch 47/500
# 6/6 [==============================] - 0s 25ms/step - loss: 1.0950 - accuracy: 0.6984 - val_loss: 2.7569 - val_accuracy: 0.4167
# Epoch 48/500
# 6/6 [==============================] - 0s 24ms/step - loss: 0.9966 - accuracy: 0.7302 - val_loss: 2.8270 - val_accuracy: 0.3958
# Epoch 49/500
# 6/6 [==============================] - 0s 23ms/step - loss: 0.9228 - accuracy: 0.7672 - val_loss: 2.9840 - val_accuracy: 0.5000
# Epoch 50/500
# 6/6 [==============================] - 0s 25ms/step - loss: 0.9316 - accuracy: 0.7672 - val_loss: 2.5417 - val_accuracy: 0.4792
# Epoch 51/500
# 6/6 [==============================] - 0s 23ms/step - loss: 1.0497 - accuracy: 0.6825 - val_loss: 2.9427 - val_accuracy: 0.5000
# Epoch 52/500
# 6/6 [==============================] - 0s 22ms/step - loss: 0.9027 - accuracy: 0.7672 - val_loss: 3.0020 - val_accuracy: 0.3958
# Epoch 53/500
# 6/6 [==============================] - 0s 33ms/step - loss: 0.9002 - accuracy: 0.7619 - val_loss: 2.8410 - val_accuracy: 0.5417
# Epoch 54/500
# 6/6 [==============================] - 0s 22ms/step - loss: 0.9083 - accuracy: 0.7354 - val_loss: 2.6342 - val_accuracy: 0.6042
# Epoch 55/500
# 6/6 [==============================] - 0s 23ms/step - loss: 0.8259 - accuracy: 0.8201 - val_loss: 3.0238 - val_accuracy: 0.4583
# Epoch 56/500
# 6/6 [==============================] - 0s 22ms/step - loss: 0.8588 - accuracy: 0.7566 - val_loss: 3.0612 - val_accuracy: 0.4375
# Epoch 57/500
# 6/6 [==============================] - 0s 23ms/step - loss: 0.9001 - accuracy: 0.7407 - val_loss: 3.0220 - val_accuracy: 0.4375
# Epoch 58/500
# 6/6 [==============================] - 0s 24ms/step - loss: 0.7600 - accuracy: 0.8042 - val_loss: 2.9388 - val_accuracy: 0.4375
# Epoch 59/500
# 6/6 [==============================] - 0s 23ms/step - loss: 0.7795 - accuracy: 0.7937 - val_loss: 2.8647 - val_accuracy: 0.5000
# Epoch 60/500
# 6/6 [==============================] - 0s 23ms/step - loss: 0.8724 - accuracy: 0.7513 - val_loss: 2.8046 - val_accuracy: 0.4792
# Epoch 61/500
# 6/6 [==============================] - 0s 23ms/step - loss: 0.7779 - accuracy: 0.7831 - val_loss: 2.8717 - val_accuracy: 0.4167
# Epoch 62/500
# 6/6 [==============================] - 0s 22ms/step - loss: 0.7806 - accuracy: 0.7989 - val_loss: 2.8525 - val_accuracy: 0.5208
# Epoch 63/500
# 6/6 [==============================] - 0s 22ms/step - loss: 0.8562 - accuracy: 0.7937 - val_loss: 2.7091 - val_accuracy: 0.4375
# Epoch 64/500
# 6/6 [==============================] - 0s 22ms/step - loss: 0.7034 - accuracy: 0.8254 - val_loss: 2.8045 - val_accuracy: 0.4792
# Epoch 65/500
# 6/6 [==============================] - 0s 23ms/step - loss: 0.6959 - accuracy: 0.8519 - val_loss: 2.8160 - val_accuracy: 0.5000
# Epoch 66/500
# 6/6 [==============================] - 0s 23ms/step - loss: 0.7464 - accuracy: 0.7884 - val_loss: 2.9927 - val_accuracy: 0.4375
# Epoch 67/500
# 6/6 [==============================] - 0s 22ms/step - loss: 0.6567 - accuracy: 0.8466 - val_loss: 2.9340 - val_accuracy: 0.5208
# Epoch 68/500
# 6/6 [==============================] - 0s 22ms/step - loss: 0.6675 - accuracy: 0.8413 - val_loss: 2.8376 - val_accuracy: 0.5208
# Epoch 69/500
# 6/6 [==============================] - 0s 22ms/step - loss: 0.5956 - accuracy: 0.8624 - val_loss: 3.1607 - val_accuracy: 0.5208
# Epoch 70/500
# 6/6 [==============================] - 0s 22ms/step - loss: 0.6969 - accuracy: 0.7778 - val_loss: 2.6667 - val_accuracy: 0.5208
# Epoch 71/500
# 6/6 [==============================] - 0s 23ms/step - loss: 0.6751 - accuracy: 0.8307 - val_loss: 3.0974 - val_accuracy: 0.5833
# Epoch 72/500
# 6/6 [==============================] - 0s 22ms/step - loss: 0.6922 - accuracy: 0.8519 - val_loss: 2.6471 - val_accuracy: 0.4583
# Epoch 73/500
# 6/6 [==============================] - 0s 23ms/step - loss: 0.6188 - accuracy: 0.8624 - val_loss: 2.7044 - val_accuracy: 0.4792
# Epoch 74/500
# 6/6 [==============================] - 0s 23ms/step - loss: 0.6263 - accuracy: 0.8783 - val_loss: 2.7865 - val_accuracy: 0.5417
# Epoch 75/500
# 6/6 [==============================] - 0s 22ms/step - loss: 0.5733 - accuracy: 0.8889 - val_loss: 2.8454 - val_accuracy: 0.5417
# Epoch 76/500
# 6/6 [==============================] - 0s 22ms/step - loss: 0.6271 - accuracy: 0.8571 - val_loss: 3.1501 - val_accuracy: 0.4792
# Epoch 77/500
# 6/6 [==============================] - 0s 22ms/step - loss: 0.5667 - accuracy: 0.8519 - val_loss: 2.8856 - val_accuracy: 0.5625
# Epoch 78/500
# 6/6 [==============================] - 0s 23ms/step - loss: 0.5626 - accuracy: 0.8889 - val_loss: 3.1765 - val_accuracy: 0.5208
# Epoch 79/500
# 6/6 [==============================] - 0s 22ms/step - loss: 0.6615 - accuracy: 0.8201 - val_loss: 2.7511 - val_accuracy: 0.5625
# Epoch 80/500
# 6/6 [==============================] - 0s 23ms/step - loss: 0.5728 - accuracy: 0.8836 - val_loss: 2.8145 - val_accuracy: 0.5833
# Epoch 81/500
# 6/6 [==============================] - 0s 22ms/step - loss: 0.6114 - accuracy: 0.8571 - val_loss: 2.9516 - val_accuracy: 0.5208
# Epoch 82/500
# 6/6 [==============================] - 0s 24ms/step - loss: 0.5730 - accuracy: 0.8783 - val_loss: 2.9042 - val_accuracy: 0.5625
# Epoch 83/500
# 6/6 [==============================] - 0s 22ms/step - loss: 0.5916 - accuracy: 0.8571 - val_loss: 3.1096 - val_accuracy: 0.4583
# Epoch 84/500
# 6/6 [==============================] - 0s 22ms/step - loss: 0.5465 - accuracy: 0.8836 - val_loss: 3.0190 - val_accuracy: 0.5208
# Epoch 85/500
# 6/6 [==============================] - 0s 23ms/step - loss: 0.5538 - accuracy: 0.8942 - val_loss: 3.0136 - val_accuracy: 0.5208
# Epoch 86/500
# 6/6 [==============================] - 0s 22ms/step - loss: 0.4401 - accuracy: 0.9153 - val_loss: 2.7908 - val_accuracy: 0.5417
# Epoch 87/500
# 6/6 [==============================] - 0s 22ms/step - loss: 0.4851 - accuracy: 0.9101 - val_loss: 2.7395 - val_accuracy: 0.5417
# Epoch 88/500
# 6/6 [==============================] - 0s 30ms/step - loss: 0.5344 - accuracy: 0.8730 - val_loss: 2.7719 - val_accuracy: 0.5000
# Epoch 89/500
# 6/6 [==============================] - 0s 22ms/step - loss: 0.4685 - accuracy: 0.9048 - val_loss: 2.7407 - val_accuracy: 0.4792
# Epoch 90/500
# 6/6 [==============================] - 0s 22ms/step - loss: 0.4705 - accuracy: 0.9153 - val_loss: 2.9020 - val_accuracy: 0.5000
# Epoch 91/500
# 6/6 [==============================] - 0s 22ms/step - loss: 0.4473 - accuracy: 0.8995 - val_loss: 3.0293 - val_accuracy: 0.4792
# Epoch 92/500
# 6/6 [==============================] - 0s 22ms/step - loss: 0.4496 - accuracy: 0.9048 - val_loss: 2.9366 - val_accuracy: 0.5000
# Epoch 93/500
# 6/6 [==============================] - 0s 24ms/step - loss: 0.4635 - accuracy: 0.9101 - val_loss: 3.0383 - val_accuracy: 0.5417
# Epoch 94/500
# 6/6 [==============================] - 0s 22ms/step - loss: 0.4001 - accuracy: 0.9259 - val_loss: 2.9291 - val_accuracy: 0.5417
# Epoch 95/500
# 6/6 [==============================] - 0s 23ms/step - loss: 0.4994 - accuracy: 0.8836 - val_loss: 3.0686 - val_accuracy: 0.4583
# Epoch 96/500
# 6/6 [==============================] - 0s 22ms/step - loss: 0.4779 - accuracy: 0.8836 - val_loss: 3.2341 - val_accuracy: 0.4583
# Epoch 97/500
# 6/6 [==============================] - 0s 22ms/step - loss: 0.4564 - accuracy: 0.9153 - val_loss: 3.3086 - val_accuracy: 0.5000
# Epoch 98/500
# 6/6 [==============================] - 0s 25ms/step - loss: 0.5214 - accuracy: 0.8677 - val_loss: 3.1010 - val_accuracy: 0.5000
# Epoch 99/500
# 6/6 [==============================] - 0s 25ms/step - loss: 0.3547 - accuracy: 0.9630 - val_loss: 2.8925 - val_accuracy: 0.5625
# Epoch 100/500
# 6/6 [==============================] - 0s 23ms/step - loss: 0.3700 - accuracy: 0.9312 - val_loss: 2.9604 - val_accuracy: 0.6042
# Epoch 101/500
# 6/6 [==============================] - 0s 24ms/step - loss: 0.4796 - accuracy: 0.9259 - val_loss: 2.8737 - val_accuracy: 0.5208
# Epoch 102/500
# 6/6 [==============================] - 0s 22ms/step - loss: 0.4208 - accuracy: 0.9365 - val_loss: 3.0596 - val_accuracy: 0.5000
# Epoch 103/500
# 6/6 [==============================] - 0s 23ms/step - loss: 0.4134 - accuracy: 0.9259 - val_loss: 3.1109 - val_accuracy: 0.5417
# Epoch 104/500
# 6/6 [==============================] - 0s 24ms/step - loss: 0.4073 - accuracy: 0.9312 - val_loss: 2.9290 - val_accuracy: 0.4792
# Epoch 105/500
# 6/6 [==============================] - 0s 24ms/step - loss: 0.4555 - accuracy: 0.8995 - val_loss: 3.2092 - val_accuracy: 0.5208
# Epoch 106/500
# 6/6 [==============================] - 0s 26ms/step - loss: 0.4433 - accuracy: 0.9206 - val_loss: 3.2078 - val_accuracy: 0.5208
# Epoch 107/500
# 6/6 [==============================] - 0s 25ms/step - loss: 0.4213 - accuracy: 0.9259 - val_loss: 3.2423 - val_accuracy: 0.4792
# Epoch 108/500
# 6/6 [==============================] - 0s 24ms/step - loss: 0.3966 - accuracy: 0.9471 - val_loss: 2.9438 - val_accuracy: 0.5625
# Epoch 109/500
# 6/6 [==============================] - 0s 24ms/step - loss: 0.4392 - accuracy: 0.9153 - val_loss: 3.2414 - val_accuracy: 0.5000
# Epoch 110/500
# 6/6 [==============================] - 0s 22ms/step - loss: 0.4305 - accuracy: 0.9259 - val_loss: 3.2495 - val_accuracy: 0.5625
# Epoch 111/500
# 6/6 [==============================] - 0s 28ms/step - loss: 0.4309 - accuracy: 0.9153 - val_loss: 3.1414 - val_accuracy: 0.5417
# Epoch 112/500
# 6/6 [==============================] - 0s 22ms/step - loss: 0.3753 - accuracy: 0.9259 - val_loss: 3.2305 - val_accuracy: 0.5417
# Epoch 113/500
# 6/6 [==============================] - 0s 24ms/step - loss: 0.4143 - accuracy: 0.9259 - val_loss: 3.0243 - val_accuracy: 0.5208
# Epoch 114/500
# 6/6 [==============================] - 0s 25ms/step - loss: 0.4775 - accuracy: 0.9101 - val_loss: 3.1436 - val_accuracy: 0.5417
# Epoch 115/500
# 6/6 [==============================] - 0s 22ms/step - loss: 0.3782 - accuracy: 0.9259 - val_loss: 3.2480 - val_accuracy: 0.5417
# Epoch 116/500
# 6/6 [==============================] - 0s 31ms/step - loss: 0.4305 - accuracy: 0.9259 - val_loss: 3.2349 - val_accuracy: 0.5417
# Epoch 117/500
# 6/6 [==============================] - 0s 23ms/step - loss: 0.4453 - accuracy: 0.9101 - val_loss: 3.1317 - val_accuracy: 0.5208
# Epoch 118/500
# 6/6 [==============================] - 0s 23ms/step - loss: 0.3893 - accuracy: 0.9418 - val_loss: 3.1123 - val_accuracy: 0.4792
# Epoch 119/500
# 6/6 [==============================] - 0s 26ms/step - loss: 0.3761 - accuracy: 0.9101 - val_loss: 3.3333 - val_accuracy: 0.6042
# Epoch 120/500
# 6/6 [==============================] - 0s 24ms/step - loss: 0.3684 - accuracy: 0.9524 - val_loss: 3.3256 - val_accuracy: 0.5833
# Epoch 121/500
# 6/6 [==============================] - 0s 22ms/step - loss: 0.3681 - accuracy: 0.9259 - val_loss: 3.2369 - val_accuracy: 0.5417
# Epoch 122/500
# 6/6 [==============================] - 0s 22ms/step - loss: 0.3910 - accuracy: 0.9206 - val_loss: 3.3644 - val_accuracy: 0.5625
# Epoch 123/500
# 6/6 [==============================] - 0s 22ms/step - loss: 0.3915 - accuracy: 0.9259 - val_loss: 3.3674 - val_accuracy: 0.5208
# Epoch 124/500
# 6/6 [==============================] - 0s 23ms/step - loss: 0.4418 - accuracy: 0.8889 - val_loss: 3.4650 - val_accuracy: 0.4375
# Epoch 125/500
# 6/6 [==============================] - 0s 23ms/step - loss: 0.3982 - accuracy: 0.9259 - val_loss: 3.8526 - val_accuracy: 0.5208
# Epoch 126/500
# 6/6 [==============================] - 0s 25ms/step - loss: 0.3875 - accuracy: 0.9153 - val_loss: 3.4476 - val_accuracy: 0.4583
# Epoch 127/500
# 6/6 [==============================] - 0s 24ms/step - loss: 0.3767 - accuracy: 0.9365 - val_loss: 3.2818 - val_accuracy: 0.5000
# Epoch 128/500
# 6/6 [==============================] - 0s 25ms/step - loss: 0.3764 - accuracy: 0.9418 - val_loss: 3.3781 - val_accuracy: 0.5208
# Epoch 129/500
# 6/6 [==============================] - 0s 28ms/step - loss: 0.3330 - accuracy: 0.9524 - val_loss: 3.1989 - val_accuracy: 0.5625
# Epoch 130/500
# 6/6 [==============================] - 0s 25ms/step - loss: 0.3201 - accuracy: 0.9577 - val_loss: 3.5464 - val_accuracy: 0.5208
# Epoch 131/500
# 6/6 [==============================] - 0s 26ms/step - loss: 0.3855 - accuracy: 0.9101 - val_loss: 3.5118 - val_accuracy: 0.5000
# Epoch 132/500
# 6/6 [==============================] - 0s 26ms/step - loss: 0.3116 - accuracy: 0.9418 - val_loss: 3.1540 - val_accuracy: 0.5208
# Epoch 133/500
# 6/6 [==============================] - 0s 22ms/step - loss: 0.3785 - accuracy: 0.9259 - val_loss: 3.0978 - val_accuracy: 0.4792
# Epoch 134/500
# 6/6 [==============================] - 0s 24ms/step - loss: 0.2862 - accuracy: 0.9630 - val_loss: 3.1046 - val_accuracy: 0.5833
# Epoch 135/500
# 6/6 [==============================] - 0s 24ms/step - loss: 0.3523 - accuracy: 0.9259 - val_loss: 3.2024 - val_accuracy: 0.5208
# Epoch 136/500
# 6/6 [==============================] - 0s 25ms/step - loss: 0.3283 - accuracy: 0.9524 - val_loss: 3.3993 - val_accuracy: 0.5417
# Epoch 137/500
# 6/6 [==============================] - 0s 22ms/step - loss: 0.3410 - accuracy: 0.9418 - val_loss: 3.2030 - val_accuracy: 0.5000
# Epoch 138/500
# 6/6 [==============================] - 0s 24ms/step - loss: 0.2933 - accuracy: 0.9788 - val_loss: 3.4101 - val_accuracy: 0.5625
# Epoch 139/500
# 6/6 [==============================] - 0s 23ms/step - loss: 0.3220 - accuracy: 0.9365 - val_loss: 3.0637 - val_accuracy: 0.5417
# Epoch 140/500
# 6/6 [==============================] - 0s 25ms/step - loss: 0.3589 - accuracy: 0.9471 - val_loss: 2.9902 - val_accuracy: 0.5417
# Epoch 141/500
# 6/6 [==============================] - 0s 28ms/step - loss: 0.3427 - accuracy: 0.9259 - val_loss: 3.5818 - val_accuracy: 0.4792
# Epoch 142/500
# 6/6 [==============================] - 0s 36ms/step - loss: 0.3229 - accuracy: 0.9365 - val_loss: 3.4735 - val_accuracy: 0.4375
# Epoch 143/500
# 6/6 [==============================] - 0s 26ms/step - loss: 0.2999 - accuracy: 0.9577 - val_loss: 3.0679 - val_accuracy: 0.4792
# Epoch 144/500
# 6/6 [==============================] - 0s 23ms/step - loss: 0.3924 - accuracy: 0.9153 - val_loss: 3.3923 - val_accuracy: 0.4792
# Epoch 145/500
# 6/6 [==============================] - 0s 23ms/step - loss: 0.3516 - accuracy: 0.9418 - val_loss: 3.3813 - val_accuracy: 0.5000
# Epoch 146/500
# 6/6 [==============================] - 0s 22ms/step - loss: 0.4410 - accuracy: 0.8995 - val_loss: 3.0431 - val_accuracy: 0.5000
# Epoch 147/500
# 6/6 [==============================] - 0s 22ms/step - loss: 0.3848 - accuracy: 0.9206 - val_loss: 2.9860 - val_accuracy: 0.6042
# Epoch 148/500
# 6/6 [==============================] - 0s 22ms/step - loss: 0.3715 - accuracy: 0.9101 - val_loss: 3.1301 - val_accuracy: 0.5417
# Epoch 149/500
# 6/6 [==============================] - 0s 24ms/step - loss: 0.3794 - accuracy: 0.9259 - val_loss: 3.0773 - val_accuracy: 0.5625
# Epoch 150/500
# 6/6 [==============================] - 0s 23ms/step - loss: 0.3125 - accuracy: 0.9524 - val_loss: 3.0428 - val_accuracy: 0.5417
# Epoch 151/500
# 6/6 [==============================] - 0s 28ms/step - loss: 0.3930 - accuracy: 0.9153 - val_loss: 3.2565 - val_accuracy: 0.5417
# Epoch 152/500
# 6/6 [==============================] - 0s 24ms/step - loss: 0.3342 - accuracy: 0.9471 - val_loss: 3.4539 - val_accuracy: 0.5417
# Epoch 153/500
# 6/6 [==============================] - 0s 24ms/step - loss: 0.3435 - accuracy: 0.9259 - val_loss: 3.2178 - val_accuracy: 0.5208
# Epoch 154/500
# 6/6 [==============================] - 0s 24ms/step - loss: 0.3233 - accuracy: 0.9524 - val_loss: 3.2122 - val_accuracy: 0.5625
# Epoch 155/500
# 6/6 [==============================] - 0s 22ms/step - loss: 0.2937 - accuracy: 0.9683 - val_loss: 3.5358 - val_accuracy: 0.5208
# Epoch 156/500
# 6/6 [==============================] - 0s 23ms/step - loss: 0.3316 - accuracy: 0.9259 - val_loss: 3.4137 - val_accuracy: 0.5000
# Epoch 157/500
# 6/6 [==============================] - 0s 22ms/step - loss: 0.2761 - accuracy: 0.9524 - val_loss: 3.2836 - val_accuracy: 0.5417
# Epoch 158/500
# 6/6 [==============================] - 0s 22ms/step - loss: 0.3024 - accuracy: 0.9418 - val_loss: 3.1206 - val_accuracy: 0.5417
# Epoch 159/500
# 6/6 [==============================] - 0s 23ms/step - loss: 0.2928 - accuracy: 0.9577 - val_loss: 3.3741 - val_accuracy: 0.5417
# Epoch 160/500
# 6/6 [==============================] - 0s 22ms/step - loss: 0.3186 - accuracy: 0.9312 - val_loss: 3.4449 - val_accuracy: 0.5000
# Epoch 161/500
# 6/6 [==============================] - 0s 23ms/step - loss: 0.3785 - accuracy: 0.9259 - val_loss: 3.2373 - val_accuracy: 0.5000
# Epoch 162/500
# 6/6 [==============================] - 0s 22ms/step - loss: 0.3056 - accuracy: 0.9365 - val_loss: 3.0449 - val_accuracy: 0.5208
# Epoch 163/500
# 6/6 [==============================] - 0s 23ms/step - loss: 0.3103 - accuracy: 0.9577 - val_loss: 2.6806 - val_accuracy: 0.5625
# Epoch 164/500
# 6/6 [==============================] - 0s 23ms/step - loss: 0.2625 - accuracy: 0.9683 - val_loss: 2.6048 - val_accuracy: 0.5833
# Epoch 165/500
# 6/6 [==============================] - 0s 23ms/step - loss: 0.3651 - accuracy: 0.9206 - val_loss: 2.7089 - val_accuracy: 0.5625
# Epoch 166/500
# 6/6 [==============================] - 0s 23ms/step - loss: 0.2800 - accuracy: 0.9630 - val_loss: 2.8702 - val_accuracy: 0.5625
# Epoch 167/500
# 6/6 [==============================] - 0s 22ms/step - loss: 0.2910 - accuracy: 0.9577 - val_loss: 2.7228 - val_accuracy: 0.6042
# Epoch 168/500
# 6/6 [==============================] - 0s 23ms/step - loss: 0.2655 - accuracy: 0.9735 - val_loss: 2.8005 - val_accuracy: 0.5417
# Epoch 169/500
# 6/6 [==============================] - 0s 22ms/step - loss: 0.3135 - accuracy: 0.9471 - val_loss: 2.9254 - val_accuracy: 0.5208
# Epoch 170/500
# 6/6 [==============================] - 0s 22ms/step - loss: 0.2448 - accuracy: 0.9735 - val_loss: 2.9980 - val_accuracy: 0.5833
# Epoch 171/500
# 6/6 [==============================] - 0s 23ms/step - loss: 0.2620 - accuracy: 0.9630 - val_loss: 2.9039 - val_accuracy: 0.5000
# Epoch 172/500
# 6/6 [==============================] - 0s 23ms/step - loss: 0.2591 - accuracy: 0.9683 - val_loss: 3.0071 - val_accuracy: 0.5625
# Epoch 173/500
# 6/6 [==============================] - 0s 33ms/step - loss: 0.3289 - accuracy: 0.9259 - val_loss: 3.2831 - val_accuracy: 0.5208
# Epoch 174/500
# 6/6 [==============================] - 0s 24ms/step - loss: 0.3010 - accuracy: 0.9418 - val_loss: 3.4310 - val_accuracy: 0.5625
# Epoch 175/500
# 6/6 [==============================] - 0s 27ms/step - loss: 0.2793 - accuracy: 0.9630 - val_loss: 3.0821 - val_accuracy: 0.5208
# Epoch 176/500
# 6/6 [==============================] - 0s 36ms/step - loss: 0.3173 - accuracy: 0.9524 - val_loss: 2.9810 - val_accuracy: 0.5208
# Epoch 177/500
# 6/6 [==============================] - 0s 28ms/step - loss: 0.2668 - accuracy: 0.9683 - val_loss: 3.2095 - val_accuracy: 0.5417
# Epoch 178/500
# 6/6 [==============================] - 0s 25ms/step - loss: 0.2550 - accuracy: 0.9630 - val_loss: 3.2086 - val_accuracy: 0.4583
# Epoch 179/500
# 6/6 [==============================] - 0s 24ms/step - loss: 0.2983 - accuracy: 0.9418 - val_loss: 3.4459 - val_accuracy: 0.5417
# Epoch 180/500
# 6/6 [==============================] - 0s 24ms/step - loss: 0.2380 - accuracy: 0.9683 - val_loss: 3.5076 - val_accuracy: 0.5625
# Epoch 181/500
# 6/6 [==============================] - 0s 39ms/step - loss: 0.2653 - accuracy: 0.9683 - val_loss: 3.3512 - val_accuracy: 0.5417
# Epoch 182/500
# 6/6 [==============================] - 0s 24ms/step - loss: 0.3020 - accuracy: 0.9418 - val_loss: 3.3573 - val_accuracy: 0.5208
# Epoch 183/500
# 6/6 [==============================] - 0s 22ms/step - loss: 0.2381 - accuracy: 0.9577 - val_loss: 3.4551 - val_accuracy: 0.5625
# Epoch 184/500
# 6/6 [==============================] - 0s 23ms/step - loss: 0.2393 - accuracy: 0.9788 - val_loss: 3.4396 - val_accuracy: 0.5625
# Epoch 185/500
# 6/6 [==============================] - 0s 22ms/step - loss: 0.2739 - accuracy: 0.9471 - val_loss: 3.0613 - val_accuracy: 0.6042
# Epoch 186/500
# 6/6 [==============================] - 0s 22ms/step - loss: 0.2472 - accuracy: 0.9577 - val_loss: 2.8831 - val_accuracy: 0.6042
# Epoch 187/500
# 6/6 [==============================] - 0s 23ms/step - loss: 0.2828 - accuracy: 0.9365 - val_loss: 3.2170 - val_accuracy: 0.5625
# Epoch 188/500
# 6/6 [==============================] - 0s 22ms/step - loss: 0.2971 - accuracy: 0.9418 - val_loss: 3.2639 - val_accuracy: 0.5208
# Epoch 189/500
# 6/6 [==============================] - 0s 23ms/step - loss: 0.2687 - accuracy: 0.9418 - val_loss: 3.2162 - val_accuracy: 0.5208
# Epoch 190/500
# 6/6 [==============================] - 0s 23ms/step - loss: 0.3307 - accuracy: 0.9259 - val_loss: 3.2396 - val_accuracy: 0.5208
# Epoch 191/500
# 6/6 [==============================] - 0s 22ms/step - loss: 0.2412 - accuracy: 0.9683 - val_loss: 3.0406 - val_accuracy: 0.5833
# Epoch 192/500
# 6/6 [==============================] - 0s 22ms/step - loss: 0.2768 - accuracy: 0.9418 - val_loss: 2.6087 - val_accuracy: 0.6042
# Epoch 193/500
# 6/6 [==============================] - 0s 23ms/step - loss: 0.2469 - accuracy: 0.9683 - val_loss: 2.7453 - val_accuracy: 0.6042
# Epoch 194/500
# 6/6 [==============================] - 0s 22ms/step - loss: 0.2782 - accuracy: 0.9630 - val_loss: 3.2013 - val_accuracy: 0.5625
# Epoch 195/500
# 6/6 [==============================] - 0s 32ms/step - loss: 0.2698 - accuracy: 0.9524 - val_loss: 3.0892 - val_accuracy: 0.5625
# Epoch 196/500
# 6/6 [==============================] - 0s 22ms/step - loss: 0.2534 - accuracy: 0.9683 - val_loss: 3.0130 - val_accuracy: 0.6042
# Epoch 197/500
# 6/6 [==============================] - 0s 22ms/step - loss: 0.2606 - accuracy: 0.9683 - val_loss: 3.5957 - val_accuracy: 0.5625
# Epoch 198/500
# 6/6 [==============================] - 0s 22ms/step - loss: 0.2471 - accuracy: 0.9683 - val_loss: 3.4329 - val_accuracy: 0.5625
# Epoch 199/500
# 6/6 [==============================] - 0s 23ms/step - loss: 0.2384 - accuracy: 0.9788 - val_loss: 2.9264 - val_accuracy: 0.5417
# Epoch 200/500
# 6/6 [==============================] - 0s 22ms/step - loss: 0.2480 - accuracy: 0.9630 - val_loss: 2.9730 - val_accuracy: 0.5833
# Epoch 201/500
# 6/6 [==============================] - 0s 22ms/step - loss: 0.3019 - accuracy: 0.9312 - val_loss: 3.1656 - val_accuracy: 0.5417
# Epoch 202/500
# 6/6 [==============================] - 0s 23ms/step - loss: 0.2329 - accuracy: 0.9788 - val_loss: 3.0676 - val_accuracy: 0.5625
# Epoch 203/500
# 6/6 [==============================] - 0s 23ms/step - loss: 0.2809 - accuracy: 0.9471 - val_loss: 3.0958 - val_accuracy: 0.5417
# Epoch 204/500
# 6/6 [==============================] - 0s 23ms/step - loss: 0.2302 - accuracy: 0.9630 - val_loss: 3.1957 - val_accuracy: 0.5000
# Epoch 205/500
# 6/6 [==============================] - 0s 22ms/step - loss: 0.2996 - accuracy: 0.9418 - val_loss: 3.3458 - val_accuracy: 0.5208
# Epoch 206/500
# 6/6 [==============================] - 0s 23ms/step - loss: 0.2679 - accuracy: 0.9524 - val_loss: 3.1801 - val_accuracy: 0.5833
# Epoch 207/500
# 6/6 [==============================] - 0s 23ms/step - loss: 0.2638 - accuracy: 0.9577 - val_loss: 3.0821 - val_accuracy: 0.5625
# Epoch 208/500
# 6/6 [==============================] - 0s 22ms/step - loss: 0.3070 - accuracy: 0.9418 - val_loss: 3.0936 - val_accuracy: 0.5625
# Epoch 209/500
# 6/6 [==============================] - 0s 23ms/step - loss: 0.3049 - accuracy: 0.9312 - val_loss: 3.1175 - val_accuracy: 0.5625
# Epoch 210/500
# 6/6 [==============================] - 0s 23ms/step - loss: 0.2417 - accuracy: 0.9841 - val_loss: 3.5174 - val_accuracy: 0.5417
# Epoch 211/500
# 6/6 [==============================] - 0s 23ms/step - loss: 0.3142 - accuracy: 0.9312 - val_loss: 3.5878 - val_accuracy: 0.5625
# Epoch 212/500
# 6/6 [==============================] - 0s 23ms/step - loss: 0.2632 - accuracy: 0.9577 - val_loss: 3.5089 - val_accuracy: 0.5417
# Epoch 213/500
# 6/6 [==============================] - 0s 22ms/step - loss: 0.2013 - accuracy: 0.9841 - val_loss: 3.5184 - val_accuracy: 0.5208
# Epoch 214/500
# 6/6 [==============================] - 0s 23ms/step - loss: 0.2820 - accuracy: 0.9471 - val_loss: 3.2113 - val_accuracy: 0.5208
# Epoch 215/500
# 6/6 [==============================] - 0s 28ms/step - loss: 0.2525 - accuracy: 0.9577 - val_loss: 2.9505 - val_accuracy: 0.5833
# Epoch 216/500
# 6/6 [==============================] - 0s 23ms/step - loss: 0.2185 - accuracy: 0.9735 - val_loss: 3.1075 - val_accuracy: 0.5625
# Epoch 217/500
# 6/6 [==============================] - 0s 23ms/step - loss: 0.2322 - accuracy: 0.9630 - val_loss: 3.1706 - val_accuracy: 0.5417
# Epoch 218/500
# 6/6 [==============================] - 0s 23ms/step - loss: 0.2550 - accuracy: 0.9683 - val_loss: 3.2790 - val_accuracy: 0.5625
# Epoch 219/500
# 6/6 [==============================] - 0s 23ms/step - loss: 0.2676 - accuracy: 0.9577 - val_loss: 3.2458 - val_accuracy: 0.5625
# Epoch 220/500
# 6/6 [==============================] - 0s 22ms/step - loss: 0.2670 - accuracy: 0.9630 - val_loss: 3.4974 - val_accuracy: 0.5208
# Epoch 221/500
# 6/6 [==============================] - 0s 22ms/step - loss: 0.2625 - accuracy: 0.9524 - val_loss: 3.5260 - val_accuracy: 0.4583
# Epoch 222/500
# 6/6 [==============================] - 0s 22ms/step - loss: 0.2713 - accuracy: 0.9683 - val_loss: 3.5919 - val_accuracy: 0.5417
# Epoch 223/500
# 6/6 [==============================] - 0s 25ms/step - loss: 0.2591 - accuracy: 0.9630 - val_loss: 3.2474 - val_accuracy: 0.5625
# Epoch 224/500
# 6/6 [==============================] - 0s 24ms/step - loss: 0.2692 - accuracy: 0.9471 - val_loss: 2.8910 - val_accuracy: 0.4583
# Epoch 225/500
# 6/6 [==============================] - 0s 24ms/step - loss: 0.2868 - accuracy: 0.9524 - val_loss: 3.0063 - val_accuracy: 0.5833
# Epoch 226/500
# 6/6 [==============================] - 0s 24ms/step - loss: 0.2396 - accuracy: 0.9577 - val_loss: 3.0042 - val_accuracy: 0.5625
# Epoch 227/500
# 6/6 [==============================] - 0s 25ms/step - loss: 0.2280 - accuracy: 0.9683 - val_loss: 3.0763 - val_accuracy: 0.5833
# Epoch 228/500
# 6/6 [==============================] - 0s 24ms/step - loss: 0.2111 - accuracy: 0.9841 - val_loss: 3.0419 - val_accuracy: 0.6042
# Epoch 229/500
# 6/6 [==============================] - 0s 25ms/step - loss: 0.2351 - accuracy: 0.9524 - val_loss: 3.1047 - val_accuracy: 0.5208
# Epoch 230/500
# 6/6 [==============================] - 0s 23ms/step - loss: 0.2579 - accuracy: 0.9630 - val_loss: 3.0753 - val_accuracy: 0.5625
# Epoch 231/500
# 6/6 [==============================] - 0s 25ms/step - loss: 0.2334 - accuracy: 0.9841 - val_loss: 2.8006 - val_accuracy: 0.5833
# Epoch 232/500
# 6/6 [==============================] - 0s 46ms/step - loss: 0.2313 - accuracy: 0.9524 - val_loss: 2.6873 - val_accuracy: 0.6250
# Epoch 233/500
# 6/6 [==============================] - 0s 25ms/step - loss: 0.2238 - accuracy: 0.9577 - val_loss: 2.6832 - val_accuracy: 0.5625
# Epoch 234/500
# 6/6 [==============================] - 0s 28ms/step - loss: 0.2360 - accuracy: 0.9683 - val_loss: 2.9043 - val_accuracy: 0.6042
# Epoch 235/500
# 6/6 [==============================] - 0s 26ms/step - loss: 0.2663 - accuracy: 0.9630 - val_loss: 3.2358 - val_accuracy: 0.6250
# Epoch 236/500
# 6/6 [==============================] - 0s 27ms/step - loss: 0.2401 - accuracy: 0.9577 - val_loss: 3.0693 - val_accuracy: 0.6250
# Epoch 237/500
# 6/6 [==============================] - 0s 25ms/step - loss: 0.2151 - accuracy: 0.9735 - val_loss: 2.9419 - val_accuracy: 0.5833
# Epoch 238/500
# 6/6 [==============================] - 0s 27ms/step - loss: 0.2194 - accuracy: 0.9788 - val_loss: 3.3128 - val_accuracy: 0.5833
# Epoch 239/500
# 6/6 [==============================] - 0s 25ms/step - loss: 0.2258 - accuracy: 0.9735 - val_loss: 3.4345 - val_accuracy: 0.6250
# Epoch 240/500
# 6/6 [==============================] - 0s 22ms/step - loss: 0.1947 - accuracy: 0.9788 - val_loss: 3.2304 - val_accuracy: 0.5417
# Epoch 241/500
# 6/6 [==============================] - 0s 23ms/step - loss: 0.2598 - accuracy: 0.9524 - val_loss: 2.8304 - val_accuracy: 0.6042
# Epoch 242/500
# 6/6 [==============================] - 0s 23ms/step - loss: 0.2181 - accuracy: 0.9683 - val_loss: 2.8673 - val_accuracy: 0.5833
# Epoch 243/500
# 6/6 [==============================] - 0s 22ms/step - loss: 0.2154 - accuracy: 0.9788 - val_loss: 3.0538 - val_accuracy: 0.5833
# Epoch 244/500
# 6/6 [==============================] - 0s 23ms/step - loss: 0.1905 - accuracy: 0.9841 - val_loss: 3.0218 - val_accuracy: 0.5208
# Epoch 245/500
# 6/6 [==============================] - 0s 23ms/step - loss: 0.2489 - accuracy: 0.9577 - val_loss: 2.9734 - val_accuracy: 0.5625
# Epoch 246/500
# 6/6 [==============================] - 0s 24ms/step - loss: 0.1690 - accuracy: 0.9841 - val_loss: 3.3464 - val_accuracy: 0.6042
# Epoch 247/500
# 6/6 [==============================] - 0s 23ms/step - loss: 0.2900 - accuracy: 0.9259 - val_loss: 3.4651 - val_accuracy: 0.5625
# Epoch 248/500
# 6/6 [==============================] - 0s 22ms/step - loss: 0.2880 - accuracy: 0.9524 - val_loss: 3.4216 - val_accuracy: 0.5417
# Epoch 249/500
# 6/6 [==============================] - 0s 31ms/step - loss: 0.2281 - accuracy: 0.9630 - val_loss: 3.1427 - val_accuracy: 0.5417
# Epoch 250/500
# 6/6 [==============================] - 0s 25ms/step - loss: 0.2491 - accuracy: 0.9524 - val_loss: 2.9360 - val_accuracy: 0.6042
# Epoch 251/500
# 6/6 [==============================] - 0s 23ms/step - loss: 0.2522 - accuracy: 0.9471 - val_loss: 3.4996 - val_accuracy: 0.5000
# Epoch 252/500
# 6/6 [==============================] - 0s 22ms/step - loss: 0.4415 - accuracy: 0.8995 - val_loss: 3.2912 - val_accuracy: 0.5417
# Epoch 253/500
# 6/6 [==============================] - 0s 24ms/step - loss: 0.3448 - accuracy: 0.9365 - val_loss: 2.7387 - val_accuracy: 0.5833
# Epoch 254/500
# 6/6 [==============================] - 0s 22ms/step - loss: 0.3256 - accuracy: 0.9312 - val_loss: 2.9220 - val_accuracy: 0.5625
# Epoch 255/500
# 6/6 [==============================] - 0s 22ms/step - loss: 0.3957 - accuracy: 0.9259 - val_loss: 3.2390 - val_accuracy: 0.5000
# Epoch 256/500
# 6/6 [==============================] - 0s 23ms/step - loss: 0.2726 - accuracy: 0.9577 - val_loss: 3.1511 - val_accuracy: 0.5625
# Epoch 257/500
# 6/6 [==============================] - 0s 23ms/step - loss: 0.3483 - accuracy: 0.9365 - val_loss: 3.3261 - val_accuracy: 0.5417
# Epoch 258/500
# 6/6 [==============================] - 0s 24ms/step - loss: 0.3078 - accuracy: 0.9418 - val_loss: 3.4947 - val_accuracy: 0.5417
# Epoch 259/500
# 6/6 [==============================] - 0s 23ms/step - loss: 0.3294 - accuracy: 0.9365 - val_loss: 3.4902 - val_accuracy: 0.5625
# Epoch 260/500
# 6/6 [==============================] - 0s 23ms/step - loss: 0.3566 - accuracy: 0.9418 - val_loss: 3.5272 - val_accuracy: 0.6042
# Epoch 261/500
# 6/6 [==============================] - 0s 25ms/step - loss: 0.3527 - accuracy: 0.9365 - val_loss: 3.5712 - val_accuracy: 0.5625
# Epoch 262/500
# 6/6 [==============================] - 0s 22ms/step - loss: 0.2901 - accuracy: 0.9577 - val_loss: 3.4973 - val_accuracy: 0.5000
# Epoch 263/500
# 6/6 [==============================] - 0s 23ms/step - loss: 0.2808 - accuracy: 0.9683 - val_loss: 3.4468 - val_accuracy: 0.5208
# Epoch 264/500
# 6/6 [==============================] - 0s 22ms/step - loss: 0.3021 - accuracy: 0.9471 - val_loss: 3.6394 - val_accuracy: 0.5625
# Epoch 265/500
# 6/6 [==============================] - 0s 22ms/step - loss: 0.2536 - accuracy: 0.9683 - val_loss: 3.8415 - val_accuracy: 0.6042
# Epoch 266/500
# 6/6 [==============================] - 0s 35ms/step - loss: 0.2502 - accuracy: 0.9683 - val_loss: 3.5985 - val_accuracy: 0.5208
# Epoch 267/500
# 6/6 [==============================] - 0s 23ms/step - loss: 0.2162 - accuracy: 0.9841 - val_loss: 3.5301 - val_accuracy: 0.4792
# Epoch 268/500
# 6/6 [==============================] - 0s 23ms/step - loss: 0.2632 - accuracy: 0.9577 - val_loss: 3.4839 - val_accuracy: 0.4583
# Epoch 269/500
# 6/6 [==============================] - 0s 22ms/step - loss: 0.2449 - accuracy: 0.9630 - val_loss: 3.3596 - val_accuracy: 0.5833
# Epoch 270/500
# 6/6 [==============================] - 0s 23ms/step - loss: 0.2636 - accuracy: 0.9577 - val_loss: 3.1536 - val_accuracy: 0.5417
# Epoch 271/500
# 6/6 [==============================] - 0s 22ms/step - loss: 0.1982 - accuracy: 0.9788 - val_loss: 3.0941 - val_accuracy: 0.5625
# Epoch 272/500
# 6/6 [==============================] - 0s 22ms/step - loss: 0.2088 - accuracy: 0.9735 - val_loss: 3.0514 - val_accuracy: 0.5417
# Epoch 273/500
# 6/6 [==============================] - 0s 22ms/step - loss: 0.2335 - accuracy: 0.9683 - val_loss: 3.2663 - val_accuracy: 0.5000
# Epoch 274/500
# 6/6 [==============================] - 0s 22ms/step - loss: 0.2112 - accuracy: 0.9841 - val_loss: 3.2381 - val_accuracy: 0.5417
# Epoch 275/500
# 6/6 [==============================] - 0s 23ms/step - loss: 0.1946 - accuracy: 0.9683 - val_loss: 3.4423 - val_accuracy: 0.5833
# Epoch 276/500
# 6/6 [==============================] - 0s 24ms/step - loss: 0.1894 - accuracy: 0.9788 - val_loss: 3.4250 - val_accuracy: 0.5625
# Epoch 277/500
# 6/6 [==============================] - 0s 22ms/step - loss: 0.1888 - accuracy: 0.9894 - val_loss: 3.2633 - val_accuracy: 0.5208
# Epoch 278/500
# 6/6 [==============================] - 0s 23ms/step - loss: 0.1808 - accuracy: 0.9788 - val_loss: 3.0711 - val_accuracy: 0.4792
# Epoch 279/500
# 6/6 [==============================] - 0s 23ms/step - loss: 0.1764 - accuracy: 0.9947 - val_loss: 3.0207 - val_accuracy: 0.5417
# Epoch 280/500
# 6/6 [==============================] - 0s 24ms/step - loss: 0.1880 - accuracy: 0.9788 - val_loss: 3.0785 - val_accuracy: 0.5417
# Epoch 281/500
# 6/6 [==============================] - 0s 22ms/step - loss: 0.2140 - accuracy: 0.9683 - val_loss: 3.0124 - val_accuracy: 0.5417
# Epoch 282/500
# 6/6 [==============================] - 0s 22ms/step - loss: 0.1938 - accuracy: 0.9683 - val_loss: 2.9624 - val_accuracy: 0.5625
# Epoch 283/500
# 6/6 [==============================] - 0s 23ms/step - loss: 0.1820 - accuracy: 0.9788 - val_loss: 2.9856 - val_accuracy: 0.5208
# Epoch 284/500
# 6/6 [==============================] - 0s 34ms/step - loss: 0.1768 - accuracy: 0.9894 - val_loss: 2.8954 - val_accuracy: 0.5417
# Epoch 285/500
# 6/6 [==============================] - 0s 22ms/step - loss: 0.2208 - accuracy: 0.9630 - val_loss: 2.8660 - val_accuracy: 0.5000
# Epoch 286/500
# 6/6 [==============================] - 0s 22ms/step - loss: 0.1777 - accuracy: 0.9788 - val_loss: 2.9062 - val_accuracy: 0.5208
# Epoch 287/500
# 6/6 [==============================] - 0s 22ms/step - loss: 0.2037 - accuracy: 0.9788 - val_loss: 2.9778 - val_accuracy: 0.5417
# Epoch 288/500
# 6/6 [==============================] - 0s 22ms/step - loss: 0.2437 - accuracy: 0.9683 - val_loss: 2.8796 - val_accuracy: 0.5625
# Epoch 289/500
# 6/6 [==============================] - 0s 22ms/step - loss: 0.1702 - accuracy: 0.9735 - val_loss: 2.9912 - val_accuracy: 0.5833
# Epoch 290/500
# 6/6 [==============================] - 0s 22ms/step - loss: 0.2349 - accuracy: 0.9735 - val_loss: 3.1157 - val_accuracy: 0.5417
# Epoch 291/500
# 6/6 [==============================] - 0s 24ms/step - loss: 0.1723 - accuracy: 0.9841 - val_loss: 3.2559 - val_accuracy: 0.5417
# Epoch 292/500
# 6/6 [==============================] - 0s 23ms/step - loss: 0.2069 - accuracy: 0.9577 - val_loss: 3.2683 - val_accuracy: 0.5625
# Epoch 293/500
# 6/6 [==============================] - 0s 22ms/step - loss: 0.1937 - accuracy: 0.9683 - val_loss: 3.2825 - val_accuracy: 0.5625
# Epoch 294/500
# 6/6 [==============================] - 0s 24ms/step - loss: 0.2285 - accuracy: 0.9577 - val_loss: 3.3139 - val_accuracy: 0.5833
# Epoch 295/500
# 6/6 [==============================] - 0s 23ms/step - loss: 0.1719 - accuracy: 0.9788 - val_loss: 3.2007 - val_accuracy: 0.5833
# Epoch 296/500
# 6/6 [==============================] - 0s 24ms/step - loss: 0.2186 - accuracy: 0.9524 - val_loss: 3.2651 - val_accuracy: 0.5208
# Epoch 297/500
# 6/6 [==============================] - 0s 23ms/step - loss: 0.2088 - accuracy: 0.9577 - val_loss: 3.5143 - val_accuracy: 0.5208
# Epoch 298/500
# 6/6 [==============================] - 0s 23ms/step - loss: 0.2308 - accuracy: 0.9683 - val_loss: 3.5221 - val_accuracy: 0.5625
# Epoch 299/500
# 6/6 [==============================] - 0s 24ms/step - loss: 0.2146 - accuracy: 0.9630 - val_loss: 3.0945 - val_accuracy: 0.6042
# Epoch 300/500
# 6/6 [==============================] - 0s 35ms/step - loss: 0.2270 - accuracy: 0.9788 - val_loss: 3.0906 - val_accuracy: 0.6042
# Epoch 301/500
# 6/6 [==============================] - 0s 23ms/step - loss: 0.1964 - accuracy: 0.9841 - val_loss: 3.2511 - val_accuracy: 0.6042
# Epoch 302/500
# 6/6 [==============================] - 0s 25ms/step - loss: 0.1843 - accuracy: 0.9788 - val_loss: 3.0919 - val_accuracy: 0.5625
# Epoch 303/500
# 6/6 [==============================] - 0s 22ms/step - loss: 0.2543 - accuracy: 0.9577 - val_loss: 3.1890 - val_accuracy: 0.6250
# Epoch 304/500
# 6/6 [==============================] - 0s 23ms/step - loss: 0.2187 - accuracy: 0.9683 - val_loss: 3.6231 - val_accuracy: 0.5833
# Epoch 305/500
# 6/6 [==============================] - 0s 22ms/step - loss: 0.2060 - accuracy: 0.9683 - val_loss: 3.6394 - val_accuracy: 0.5417
# Epoch 306/500
# 6/6 [==============================] - 0s 24ms/step - loss: 0.1713 - accuracy: 0.9841 - val_loss: 3.6543 - val_accuracy: 0.5625
# Epoch 307/500
# 6/6 [==============================] - 0s 24ms/step - loss: 0.2344 - accuracy: 0.9683 - val_loss: 3.4853 - val_accuracy: 0.5625
# Epoch 308/500
# 6/6 [==============================] - 0s 23ms/step - loss: 0.2016 - accuracy: 0.9841 - val_loss: 3.4405 - val_accuracy: 0.5417
# Epoch 309/500
# 6/6 [==============================] - 0s 23ms/step - loss: 0.1600 - accuracy: 0.9841 - val_loss: 3.4542 - val_accuracy: 0.5208
# Epoch 310/500
# 6/6 [==============================] - 0s 29ms/step - loss: 0.2107 - accuracy: 0.9630 - val_loss: 3.4212 - val_accuracy: 0.5625
# Epoch 311/500
# 6/6 [==============================] - 0s 24ms/step - loss: 0.1765 - accuracy: 0.9841 - val_loss: 3.7035 - val_accuracy: 0.5833
# Epoch 312/500
# 6/6 [==============================] - 0s 23ms/step - loss: 0.1909 - accuracy: 0.9788 - val_loss: 3.7935 - val_accuracy: 0.5833
# Epoch 313/500
# 6/6 [==============================] - 0s 23ms/step - loss: 0.1698 - accuracy: 0.9735 - val_loss: 3.7965 - val_accuracy: 0.5417
# Epoch 314/500
# 6/6 [==============================] - 0s 36ms/step - loss: 0.2089 - accuracy: 0.9683 - val_loss: 3.4453 - val_accuracy: 0.5625
# Epoch 315/500
# 6/6 [==============================] - 0s 23ms/step - loss: 0.1875 - accuracy: 0.9735 - val_loss: 3.3847 - val_accuracy: 0.6042
# Epoch 316/500
# 6/6 [==============================] - 0s 22ms/step - loss: 0.2169 - accuracy: 0.9630 - val_loss: 3.8741 - val_accuracy: 0.5625
# Epoch 317/500
# 6/6 [==============================] - 0s 25ms/step - loss: 0.2113 - accuracy: 0.9683 - val_loss: 3.7214 - val_accuracy: 0.5417
# Epoch 318/500
# 6/6 [==============================] - 0s 23ms/step - loss: 0.2693 - accuracy: 0.9312 - val_loss: 2.9261 - val_accuracy: 0.5625
# Epoch 319/500
# 6/6 [==============================] - 0s 23ms/step - loss: 0.2669 - accuracy: 0.9471 - val_loss: 3.5299 - val_accuracy: 0.5625
# Epoch 320/500
# 6/6 [==============================] - 0s 24ms/step - loss: 0.2482 - accuracy: 0.9524 - val_loss: 2.9219 - val_accuracy: 0.5417
# Epoch 321/500
# 6/6 [==============================] - 0s 22ms/step - loss: 0.2630 - accuracy: 0.9524 - val_loss: 2.6937 - val_accuracy: 0.5833
# Epoch 322/500
# 6/6 [==============================] - 0s 23ms/step - loss: 0.2567 - accuracy: 0.9471 - val_loss: 2.8026 - val_accuracy: 0.6667
# Epoch 323/500
# 6/6 [==============================] - 0s 22ms/step - loss: 0.2634 - accuracy: 0.9524 - val_loss: 2.7444 - val_accuracy: 0.6250
# Epoch 324/500
# 6/6 [==============================] - 0s 22ms/step - loss: 0.2714 - accuracy: 0.9524 - val_loss: 3.1972 - val_accuracy: 0.5000
# Epoch 325/500
# 6/6 [==============================] - 0s 22ms/step - loss: 0.4258 - accuracy: 0.9101 - val_loss: 3.4820 - val_accuracy: 0.5625
# Epoch 326/500
# 6/6 [==============================] - 0s 23ms/step - loss: 0.3830 - accuracy: 0.8995 - val_loss: 3.1121 - val_accuracy: 0.5417
# Epoch 327/500
# 6/6 [==============================] - 0s 24ms/step - loss: 0.2975 - accuracy: 0.9418 - val_loss: 2.9317 - val_accuracy: 0.6250
# Epoch 328/500
# 6/6 [==============================] - 0s 24ms/step - loss: 0.3383 - accuracy: 0.9153 - val_loss: 3.0513 - val_accuracy: 0.6250
# Epoch 329/500
# 6/6 [==============================] - 0s 22ms/step - loss: 0.3500 - accuracy: 0.9259 - val_loss: 3.3728 - val_accuracy: 0.5208
# Epoch 330/500
# 6/6 [==============================] - 0s 22ms/step - loss: 0.3170 - accuracy: 0.9418 - val_loss: 3.4278 - val_accuracy: 0.6042
# Epoch 331/500
# 6/6 [==============================] - 0s 21ms/step - loss: 0.2909 - accuracy: 0.9577 - val_loss: 3.1271 - val_accuracy: 0.5625
# Epoch 332/500
# 6/6 [==============================] - 0s 21ms/step - loss: 0.3908 - accuracy: 0.9312 - val_loss: 3.5835 - val_accuracy: 0.5000
# Epoch 333/500
# 6/6 [==============================] - 0s 22ms/step - loss: 0.3753 - accuracy: 0.9471 - val_loss: 3.9676 - val_accuracy: 0.5208
# Epoch 334/500
# 6/6 [==============================] - 0s 23ms/step - loss: 0.3916 - accuracy: 0.9312 - val_loss: 3.7157 - val_accuracy: 0.5417
# Epoch 335/500
# 6/6 [==============================] - 0s 34ms/step - loss: 0.3043 - accuracy: 0.9524 - val_loss: 3.6932 - val_accuracy: 0.5625
# Epoch 336/500
# 6/6 [==============================] - 0s 22ms/step - loss: 0.2962 - accuracy: 0.9577 - val_loss: 3.9582 - val_accuracy: 0.5625
# Epoch 337/500
# 6/6 [==============================] - 0s 21ms/step - loss: 0.2896 - accuracy: 0.9577 - val_loss: 3.8618 - val_accuracy: 0.5208
# Epoch 338/500
# 6/6 [==============================] - 0s 23ms/step - loss: 0.2755 - accuracy: 0.9524 - val_loss: 3.8367 - val_accuracy: 0.5417
# Epoch 339/500
# ...
# Epoch 389/500
# 6/6 [==============================] - 0s 23ms/step - loss: 0.1857 - accuracy: 0.9683 - val_loss: 3.1527 - val_accuracy: 0.5833
# Epoch 390/500
# 6/6 [==============================] - 0s 23ms/step - loss: 0.1454 - accuracy: 1.0000 - val_loss: 3.0389 - val_accuracy: 0.5417
# Epoch 391/500
# 6/6 [==============================] - 0s 22ms/step - loss: 0.1752 - accuracy: 0.9788 - val_loss: 3.0900 - val_accuracy: 0.5208
# Epoch 392/500
# 6/6 [==============================] - 0s 22ms/step - loss: 0.1509 - accuracy: 0.9894 - val_loss: 3.1724 - val_accuracy: 0.5833
# Epoch 393/500
# 6/6 [==============================] - 0s 23ms/step - loss: 0.1293 - accuracy: 0.9894 - val_loss: 3.3221 - val_accuracy: 0.6042
# Epoch 394/500
# 6/6 [==============================] - 0s 23ms/step - loss: 0.1787 - accuracy: 0.9735 - val_loss: 3.5329 - val_accuracy: 0.5833
# Epoch 395/500
# 6/6 [==============================] - 0s 22ms/step - loss: 0.1808 - accuracy: 0.9524 - val_loss: 3.6486 - val_accuracy: 0.5833
# Epoch 396/500
# 6/6 [==============================] - 0s 23ms/step - loss: 0.1965 - accuracy: 0.9577 - val_loss: 3.6589 - val_accuracy: 0.5625
# Epoch 397/500
# 6/6 [==============================] - 0s 22ms/step - loss: 0.1993 - accuracy: 0.9683 - val_loss: 3.5651 - val_accuracy: 0.5625
# Epoch 398/500
# 6/6 [==============================] - 0s 23ms/step - loss: 0.2430 - accuracy: 0.9418 - val_loss: 3.5339 - val_accuracy: 0.5417
# Epoch 399/500
# 6/6 [==============================] - 0s 22ms/step - loss: 0.2192 - accuracy: 0.9577 - val_loss: 3.6478 - val_accuracy: 0.5625
# Epoch 400/500
# 6/6 [==============================] - 0s 23ms/step - loss: 0.1422 - accuracy: 0.9894 - val_loss: 3.8714 - val_accuracy: 0.5417
# Epoch 401/500
# 6/6 [==============================] - 0s 22ms/step - loss: 0.2303 - accuracy: 0.9471 - val_loss: 3.8631 - val_accuracy: 0.5208
# Epoch 402/500
# 6/6 [==============================] - 0s 23ms/step - loss: 0.1715 - accuracy: 0.9841 - val_loss: 3.3182 - val_accuracy: 0.5833
# Epoch 403/500
# 6/6 [==============================] - 0s 30ms/step - loss: 0.1729 - accuracy: 0.9683 - val_loss: 3.0767 - val_accuracy: 0.6667
# Epoch 404/500
# 6/6 [==============================] - 0s 23ms/step - loss: 0.2012 - accuracy: 0.9735 - val_loss: 3.2391 - val_accuracy: 0.5833
# Epoch 405/500
# 6/6 [==============================] - 0s 26ms/step - loss: 0.1975 - accuracy: 0.9577 - val_loss: 3.5843 - val_accuracy: 0.6042
# Epoch 406/500
# 6/6 [==============================] - 0s 22ms/step - loss: 0.2175 - accuracy: 0.9418 - val_loss: 3.5576 - val_accuracy: 0.6042
# Epoch 407/500
# 6/6 [==============================] - 0s 22ms/step - loss: 0.1827 - accuracy: 0.9735 - val_loss: 3.4991 - val_accuracy: 0.5833
# Epoch 408/500
# 6/6 [==============================] - 0s 22ms/step - loss: 0.2158 - accuracy: 0.9630 - val_loss: 3.4107 - val_accuracy: 0.6250
# Epoch 409/500
# 6/6 [==============================] - 0s 23ms/step - loss: 0.1868 - accuracy: 0.9894 - val_loss: 3.4255 - val_accuracy: 0.6250
# Epoch 410/500
# 6/6 [==============================] - 0s 22ms/step - loss: 0.2137 - accuracy: 0.9630 - val_loss: 3.5215 - val_accuracy: 0.5833
# Epoch 411/500
# 6/6 [==============================] - 0s 24ms/step - loss: 0.1596 - accuracy: 0.9788 - val_loss: 3.5042 - val_accuracy: 0.5625
# Epoch 412/500
# 6/6 [==============================] - 0s 25ms/step - loss: 0.2032 - accuracy: 0.9683 - val_loss: 3.4995 - val_accuracy: 0.5625
# Epoch 413/500
# 6/6 [==============================] - 0s 27ms/step - loss: 0.1948 - accuracy: 0.9841 - val_loss: 3.5761 - val_accuracy: 0.5625
# Epoch 414/500
# 6/6 [==============================] - 0s 29ms/step - loss: 0.1861 - accuracy: 0.9735 - val_loss: 3.7301 - val_accuracy: 0.5625
# Epoch 415/500
# 6/6 [==============================] - 0s 23ms/step - loss: 0.1521 - accuracy: 0.9894 - val_loss: 3.7198 - val_accuracy: 0.5625
# Epoch 416/500
# 6/6 [==============================] - 0s 23ms/step - loss: 0.1769 - accuracy: 0.9788 - val_loss: 3.6987 - val_accuracy: 0.5833
# Epoch 417/500
# 6/6 [==============================] - 0s 22ms/step - loss: 0.1831 - accuracy: 0.9788 - val_loss: 3.8169 - val_accuracy: 0.5833
# Epoch 418/500
# 6/6 [==============================] - 0s 22ms/step - loss: 0.1657 - accuracy: 0.9841 - val_loss: 3.8764 - val_accuracy: 0.5833
# Epoch 419/500
# 6/6 [==============================] - 0s 23ms/step - loss: 0.2061 - accuracy: 0.9683 - val_loss: 3.8427 - val_accuracy: 0.6042
# Epoch 420/500
# 6/6 [==============================] - 0s 28ms/step - loss: 0.1905 - accuracy: 0.9788 - val_loss: 3.9432 - val_accuracy: 0.6042
# Epoch 421/500
# 6/6 [==============================] - 0s 26ms/step - loss: 0.1753 - accuracy: 0.9894 - val_loss: 3.5571 - val_accuracy: 0.6250
# Epoch 422/500
# 6/6 [==============================] - 0s 26ms/step - loss: 0.2137 - accuracy: 0.9524 - val_loss: 3.2242 - val_accuracy: 0.6250
# Epoch 423/500
# 6/6 [==============================] - 0s 22ms/step - loss: 0.1984 - accuracy: 0.9630 - val_loss: 3.2200 - val_accuracy: 0.6042
# Epoch 424/500
# 6/6 [==============================] - 0s 40ms/step - loss: 0.1774 - accuracy: 0.9683 - val_loss: 3.5186 - val_accuracy: 0.5625
# Epoch 425/500
# 6/6 [==============================] - 0s 23ms/step - loss: 0.1646 - accuracy: 0.9841 - val_loss: 3.6424 - val_accuracy: 0.5208
# Epoch 426/500
# 6/6 [==============================] - 0s 22ms/step - loss: 0.1877 - accuracy: 0.9788 - val_loss: 3.7375 - val_accuracy: 0.5625
# Epoch 427/500
# 6/6 [==============================] - 0s 22ms/step - loss: 0.2355 - accuracy: 0.9471 - val_loss: 3.4044 - val_accuracy: 0.5417
# Epoch 428/500
# 6/6 [==============================] - 0s 29ms/step - loss: 0.2256 - accuracy: 0.9683 - val_loss: 3.7487 - val_accuracy: 0.5208
# Epoch 429/500
# 6/6 [==============================] - 0s 23ms/step - loss: 0.1654 - accuracy: 0.9841 - val_loss: 4.0681 - val_accuracy: 0.5417
# Epoch 430/500
# 6/6 [==============================] - 0s 23ms/step - loss: 0.2026 - accuracy: 0.9735 - val_loss: 3.4449 - val_accuracy: 0.5208
# Epoch 431/500
# 6/6 [==============================] - 0s 23ms/step - loss: 0.1974 - accuracy: 0.9735 - val_loss: 3.4982 - val_accuracy: 0.5417
# Epoch 432/500
# 6/6 [==============================] - 0s 23ms/step - loss: 0.2380 - accuracy: 0.9471 - val_loss: 3.7271 - val_accuracy: 0.5000
# Epoch 433/500
# 6/6 [==============================] - 0s 23ms/step - loss: 0.1872 - accuracy: 0.9683 - val_loss: 3.9260 - val_accuracy: 0.5208
# Epoch 434/500
# 6/6 [==============================] - 0s 23ms/step - loss: 0.1722 - accuracy: 0.9894 - val_loss: 3.9002 - val_accuracy: 0.5417
# Epoch 435/500
# 6/6 [==============================] - 0s 22ms/step - loss: 0.1871 - accuracy: 0.9630 - val_loss: 4.2942 - val_accuracy: 0.5208
# Epoch 436/500
# 6/6 [==============================] - 0s 22ms/step - loss: 0.1688 - accuracy: 0.9894 - val_loss: 4.0685 - val_accuracy: 0.5833
# Epoch 437/500
# 6/6 [==============================] - 0s 23ms/step - loss: 0.1790 - accuracy: 0.9735 - val_loss: 3.5601 - val_accuracy: 0.6250
# Epoch 438/500
# 6/6 [==============================] - 0s 26ms/step - loss: 0.1606 - accuracy: 0.9841 - val_loss: 3.4290 - val_accuracy: 0.5417
# Epoch 439/500
# 6/6 [==============================] - 0s 30ms/step - loss: 0.1840 - accuracy: 0.9735 - val_loss: 3.5388 - val_accuracy: 0.5625
# Epoch 440/500
# 6/6 [==============================] - 0s 27ms/step - loss: 0.2042 - accuracy: 0.9683 - val_loss: 3.7267 - val_accuracy: 0.5625
# Epoch 441/500
# 6/6 [==============================] - 0s 25ms/step - loss: 0.2009 - accuracy: 0.9683 - val_loss: 3.2664 - val_accuracy: 0.5417
# Epoch 442/500
# 6/6 [==============================] - 0s 26ms/step - loss: 0.1837 - accuracy: 0.9788 - val_loss: 3.3374 - val_accuracy: 0.5417
# Epoch 443/500
# 6/6 [==============================] - 0s 27ms/step - loss: 0.2049 - accuracy: 0.9630 - val_loss: 3.7032 - val_accuracy: 0.5625
# Epoch 444/500
# 6/6 [==============================] - 0s 28ms/step - loss: 0.1879 - accuracy: 0.9630 - val_loss: 3.1733 - val_accuracy: 0.6042
# Epoch 445/500
# 6/6 [==============================] - 0s 27ms/step - loss: 0.2245 - accuracy: 0.9471 - val_loss: 3.2410 - val_accuracy: 0.5625
# Epoch 446/500
# 6/6 [==============================] - 0s 31ms/step - loss: 0.2463 - accuracy: 0.9577 - val_loss: 4.1108 - val_accuracy: 0.5208
# Epoch 447/500
# 6/6 [==============================] - 0s 39ms/step - loss: 0.3131 - accuracy: 0.9312 - val_loss: 3.5498 - val_accuracy: 0.5833
# Epoch 448/500
# 6/6 [==============================] - 0s 27ms/step - loss: 0.2584 - accuracy: 0.9418 - val_loss: 3.5900 - val_accuracy: 0.6042
# Epoch 449/500
# 6/6 [==============================] - 0s 35ms/step - loss: 0.2301 - accuracy: 0.9735 - val_loss: 4.3906 - val_accuracy: 0.5833
# Epoch 450/500
# 6/6 [==============================] - 0s 30ms/step - loss: 0.2645 - accuracy: 0.9524 - val_loss: 4.7508 - val_accuracy: 0.5625
# Epoch 451/500
# 6/6 [==============================] - 0s 28ms/step - loss: 0.2157 - accuracy: 0.9735 - val_loss: 4.3370 - val_accuracy: 0.5625
# Epoch 452/500
# 6/6 [==============================] - 0s 28ms/step - loss: 0.2649 - accuracy: 0.9418 - val_loss: 4.0723 - val_accuracy: 0.5625
# Epoch 453/500
# 6/6 [==============================] - 0s 29ms/step - loss: 0.2499 - accuracy: 0.9577 - val_loss: 3.9970 - val_accuracy: 0.5000
# Epoch 454/500
# 6/6 [==============================] - 0s 41ms/step - loss: 0.2527 - accuracy: 0.9577 - val_loss: 4.1085 - val_accuracy: 0.5000
# Epoch 455/500
# 6/6 [==============================] - 0s 31ms/step - loss: 0.2397 - accuracy: 0.9735 - val_loss: 4.1338 - val_accuracy: 0.5833
# Epoch 456/500
# 6/6 [==============================] - 0s 27ms/step - loss: 0.2649 - accuracy: 0.9630 - val_loss: 3.9248 - val_accuracy: 0.6042
# Epoch 457/500
# 6/6 [==============================] - 0s 25ms/step - loss: 0.2105 - accuracy: 0.9788 - val_loss: 4.4562 - val_accuracy: 0.5417
# Epoch 458/500
# 6/6 [==============================] - 0s 29ms/step - loss: 0.2448 - accuracy: 0.9630 - val_loss: 4.4674 - val_accuracy: 0.5417
# Epoch 459/500
# 6/6 [==============================] - 0s 27ms/step - loss: 0.2031 - accuracy: 0.9735 - val_loss: 4.3694 - val_accuracy: 0.5625
# Epoch 460/500
# 6/6 [==============================] - 0s 27ms/step - loss: 0.1881 - accuracy: 0.9947 - val_loss: 4.4346 - val_accuracy: 0.5833
# Epoch 461/500
# 6/6 [==============================] - 0s 28ms/step - loss: 0.2136 - accuracy: 0.9788 - val_loss: 4.5734 - val_accuracy: 0.5625
# Epoch 462/500
# 6/6 [==============================] - 0s 31ms/step - loss: 0.1898 - accuracy: 0.9788 - val_loss: 3.9768 - val_accuracy: 0.6042
# Epoch 463/500
# 6/6 [==============================] - 0s 39ms/step - loss: 0.1752 - accuracy: 0.9841 - val_loss: 3.5320 - val_accuracy: 0.6250
# Epoch 464/500
# 6/6 [==============================] - 0s 27ms/step - loss: 0.2695 - accuracy: 0.9471 - val_loss: 3.3298 - val_accuracy: 0.6042
# Epoch 465/500
# 6/6 [==============================] - 0s 27ms/step - loss: 0.1762 - accuracy: 0.9735 - val_loss: 3.4096 - val_accuracy: 0.6250
# Epoch 466/500
# 6/6 [==============================] - 0s 27ms/step - loss: 0.1604 - accuracy: 0.9947 - val_loss: 3.5428 - val_accuracy: 0.6042
# Epoch 467/500
# 6/6 [==============================] - 0s 26ms/step - loss: 0.1956 - accuracy: 0.9735 - val_loss: 3.5864 - val_accuracy: 0.5833
# Epoch 468/500
# 6/6 [==============================] - 0s 27ms/step - loss: 0.1648 - accuracy: 0.9894 - val_loss: 3.6025 - val_accuracy: 0.6042
# Epoch 469/500
# 6/6 [==============================] - 0s 33ms/step - loss: 0.1612 - accuracy: 0.9841 - val_loss: 3.6848 - val_accuracy: 0.6042
# Epoch 470/500
# 6/6 [==============================] - 0s 27ms/step - loss: 0.1925 - accuracy: 0.9735 - val_loss: 3.7227 - val_accuracy: 0.6458
# Epoch 471/500
# 6/6 [==============================] - 0s 26ms/step - loss: 0.1683 - accuracy: 0.9788 - val_loss: 3.7592 - val_accuracy: 0.6250
# Epoch 472/500
# 6/6 [==============================] - 0s 27ms/step - loss: 0.1873 - accuracy: 0.9683 - val_loss: 3.5843 - val_accuracy: 0.6042
# Epoch 473/500
# 6/6 [==============================] - 0s 36ms/step - loss: 0.1627 - accuracy: 0.9841 - val_loss: 3.4162 - val_accuracy: 0.5833
# Epoch 474/500
# 6/6 [==============================] - 0s 28ms/step - loss: 0.1496 - accuracy: 0.9841 - val_loss: 3.3867 - val_accuracy: 0.5833
# Epoch 475/500
# 6/6 [==============================] - 0s 28ms/step - loss: 0.1756 - accuracy: 0.9894 - val_loss: 3.3578 - val_accuracy: 0.5833
# Epoch 476/500
# 6/6 [==============================] - 0s 28ms/step - loss: 0.1743 - accuracy: 0.9735 - val_loss: 3.3087 - val_accuracy: 0.6042
# Epoch 477/500
# 6/6 [==============================] - 0s 26ms/step - loss: 0.1784 - accuracy: 0.9683 - val_loss: 3.4024 - val_accuracy: 0.6042
# Epoch 478/500
# 6/6 [==============================] - 0s 27ms/step - loss: 0.1448 - accuracy: 0.9894 - val_loss: 3.4319 - val_accuracy: 0.5833
# Epoch 479/500
# 6/6 [==============================] - 0s 27ms/step - loss: 0.1371 - accuracy: 0.9894 - val_loss: 3.5481 - val_accuracy: 0.5833
# Epoch 480/500
# 6/6 [==============================] - 0s 27ms/step - loss: 0.1832 - accuracy: 0.9577 - val_loss: 3.7999 - val_accuracy: 0.5833
# Epoch 481/500
# 6/6 [==============================] - 0s 27ms/step - loss: 0.1573 - accuracy: 0.9788 - val_loss: 3.7927 - val_accuracy: 0.6042
# Epoch 482/500
# 6/6 [==============================] - 0s 33ms/step - loss: 0.1634 - accuracy: 0.9788 - val_loss: 3.6232 - val_accuracy: 0.6042
# Epoch 483/500
# 6/6 [==============================] - 0s 40ms/step - loss: 0.1690 - accuracy: 0.9683 - val_loss: 3.4967 - val_accuracy: 0.6042
# Epoch 484/500
# 6/6 [==============================] - 0s 33ms/step - loss: 0.1455 - accuracy: 0.9735 - val_loss: 3.4819 - val_accuracy: 0.5625
# Epoch 485/500
# 6/6 [==============================] - 0s 30ms/step - loss: 0.1712 - accuracy: 0.9788 - val_loss: 3.5628 - val_accuracy: 0.5625
# Epoch 486/500
# 6/6 [==============================] - 0s 29ms/step - loss: 0.1574 - accuracy: 0.9735 - val_loss: 3.4572 - val_accuracy: 0.5625
# Epoch 487/500
# 6/6 [==============================] - 0s 28ms/step - loss: 0.1585 - accuracy: 0.9788 - val_loss: 3.4762 - val_accuracy: 0.5625
# Epoch 488/500
# 6/6 [==============================] - 0s 32ms/step - loss: 0.1886 - accuracy: 0.9735 - val_loss: 3.2656 - val_accuracy: 0.5208
# Epoch 489/500
# 6/6 [==============================] - 0s 29ms/step - loss: 0.2074 - accuracy: 0.9630 - val_loss: 3.0869 - val_accuracy: 0.5417
# Epoch 490/500
# 6/6 [==============================] - 0s 30ms/step - loss: 0.2102 - accuracy: 0.9735 - val_loss: 3.0193 - val_accuracy: 0.6042
# Epoch 491/500
# 6/6 [==============================] - 0s 27ms/step - loss: 0.1872 - accuracy: 0.9735 - val_loss: 3.2355 - val_accuracy: 0.6042
# Epoch 492/500
# 6/6 [==============================] - 0s 37ms/step - loss: 0.1652 - accuracy: 0.9735 - val_loss: 3.0796 - val_accuracy: 0.5833
# Epoch 493/500
# 6/6 [==============================] - 0s 27ms/step - loss: 0.1793 - accuracy: 0.9841 - val_loss: 2.9736 - val_accuracy: 0.6042
# Epoch 494/500
# 6/6 [==============================] - 0s 27ms/step - loss: 0.1713 - accuracy: 0.9788 - val_loss: 3.0150 - val_accuracy: 0.5833
# Epoch 495/500
# 6/6 [==============================] - 0s 29ms/step - loss: 0.1960 - accuracy: 0.9577 - val_loss: 3.1683 - val_accuracy: 0.6042
# Epoch 496/500
# 6/6 [==============================] - 0s 25ms/step - loss: 0.1659 - accuracy: 0.9841 - val_loss: 3.2980 - val_accuracy: 0.6250
# Epoch 497/500
# 6/6 [==============================] - 0s 26ms/step - loss: 0.1471 - accuracy: 0.9894 - val_loss: 3.3107 - val_accuracy: 0.6042
# Epoch 498/500
# 6/6 [==============================] - 0s 27ms/step - loss: 0.1519 - accuracy: 0.9894 - val_loss: 3.3948 - val_accuracy: 0.5833
# Epoch 499/500
# 6/6 [==============================] - 0s 26ms/step - loss: 0.1435 - accuracy: 0.9841 - val_loss: 3.3130 - val_accuracy: 0.5833
# Epoch 500/500
# 6/6 [==============================] - 0s 30ms/step - loss: 0.1811 - accuracy: 0.9683 - val_loss: 3.0891 - val_accuracy: 0.5833

# %%
#diisi dengan plot hasil accuray dan loss training dan testing


# Plot utility
def plot_graphs(history, string):
  plt.plot(history.history[string])
  plt.plot(history.history['val_'+string])
  plt.xlabel("Epochs")
  plt.ylabel(string)
  plt.legend([string, 'val_'+string])
  plt.show()

# Plot the accuracy
plot_graphs(history, "accuracy")

# %%
model.save('model.h5', history)
print("model created")
# Out:
# model created

# %%
# # Membuat Input Chat
# while True:
#   texts_p = []
#   prediction_input = input('👨‍🦰 Kamu : ')

#   # Menghapus punktuasi dan konversi ke huruf kecil
#   prediction_input = [letters.lower() for letters in prediction_input if letters not in string.punctuation]
#   prediction_input = ''.join(prediction_input)
#   texts_p.append(prediction_input)

#   # Tokenisasi dan Padding
#   prediction_input = tokenizer.texts_to_sequences(texts_p)
#   prediction_input = np.array(prediction_input).reshape(-1)
#   prediction_input = pad_sequences([prediction_input],max_sequence_length)

#   # Mendapatkan hasil keluaran pada model
#   output = model.predict(prediction_input)
#   output = output.argmax()

#   # Menemukan respon sesuai data tag
#   response_tag = le.inverse_transform([output])[0]
#   print("🤖 ChatbotX :",random.choice(responses[response_tag]))
#   if response_tag == "goodbye":
#     break

# %%
# #diisi dengan save model h5 dan converter tflite
# import joblib

# %%
# # Save the model to a file
# joblib.dump(model, 'chatbot_model.pkl')

# %%
# # Save the model to a file
# joblib.dump(history, 'history_model.pkl')

# %%
# # Load the model from the file
# chatbot_model = joblib.load('chatbot_model.pkl')

# %%
# print(chatbot_model.summary())

# %%
# # Membuat Input Chat
# while True:
#   texts_p = []
#   prediction_input = input('👨‍🦰 Kamu : ')

#   # Menghapus punktuasi dan konversi ke huruf kecil
#   prediction_input = [letters.lower() for letters in prediction_input if letters not in string.punctuation]
#   prediction_input = ''.join(prediction_input)
#   texts_p.append(prediction_input)

#   # Tokenisasi dan Padding
#   prediction_input = tokenizer.texts_to_sequences(texts_p)
#   prediction_input = np.array(prediction_input).reshape(-1)
#   prediction_input = pad_sequences([prediction_input],max_sequence_length)

#   # Mendapatkan hasil keluaran pada model
#   output = chatbot_model.predict(prediction_input)
#   output = output.argmax()

#   # Menemukan respon sesuai data tag
#   response_tag = le.inverse_transform([output])[0]
#   print("🤖 ChatbotX :",random.choice(responses[response_tag]))
#   if response_tag == "goodbye":
#     break

# %%
# from flask import Flask, render_template, request
# import numpy as np
# from tensorflow.keras.preprocessing.sequence import pad_sequences
# import random
# import string

# app = Flask(__name__)

# # Define your model and tokenizer here
# # chatbot_model = 'chatbot_model'
# # tokenizer = ''
# # max_sequence_length = ''
# # le = ''
# # responses = ''

# @app.route('/')
# def home():
#     return "hey"

# @app.route('/chat', methods=['POST'])
# def chat():
#     texts_p = []
#     prediction_input = request.form['message']

#     # Remove punctuation and convert to lowercase
#     prediction_input = [letter.lower() for letter in prediction_input if letter not in string.punctuation]
#     prediction_input = ''.join(prediction_input)
#     texts_p.append(prediction_input)

#     # Tokenize and pad the input
#     prediction_input = tokenizer.texts_to_sequences(texts_p)
#     prediction_input = np.array(prediction_input).reshape(-1)
#     prediction_input = pad_sequences([prediction_input], max_sequence_length)

#     # Get the model's output prediction
#     output = chatbot_model.predict(prediction_input)
#     output = output.argmax()

#     # Find the corresponding response based on the predicted tag
#     response_tag = le.inverse_transform([output])[0]
#     response = random.choice(responses[response_tag])

#     return {'response': response}

# if __name__ == '__main__':
#     app.run()
